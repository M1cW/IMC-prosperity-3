# %%
import pandas as pd
# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('tutorial_data.csv', sep=';', header=0, index_col=0)
df
# Out:
#      timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# day
# -1           0  RAINFOREST_RESIN        10002             1       9996.0
# -1           0              KELP         2028             1       2026.0
# -1         100              KELP         2025            24          NaN
# -1         100  RAINFOREST_RESIN         9996             2       9995.0
# -1         200  RAINFOREST_RESIN         9995            20          NaN
# ..         ...               ...          ...           ...          ...
# -1      199700              KELP         2020            27          NaN
# -1      199800  RAINFOREST_RESIN         9995            21          NaN
# -1      199800              KELP         2020            21          NaN
# -1      199900              KELP         2020            32          NaN
# -1      199900  RAINFOREST_RESIN         9996             2       9995.0
#
#      bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# day
# ...

# %%
#rainforest_resin = df.where(df['product'] == 'RAINFOREST_RESIN')
#rainforest_resin.dropna()

# %%
table = Table.read_table('tutorial_data.csv', sep=';', header=0, index_col=0)
rainforest_resin = table.where('product', 'RAINFOREST_RESIN')
rainforest_resin
# Out:
# timestamp | product          | bid_price_1 | bid_volume_1 | bid_price_2 | bid_volume_2 | bid_price_3 | bid_volume_3 | ask_price_1 | ask_volume_1 | ask_price_2 | ask_volume_2 | ask_price_3 | ask_volume_3 | mid_price | profit_and_loss
# 0         | RAINFOREST_RESIN | 10002       | 1            | 9996        | 2            | 9995        | 29           | 10004       | 2            | 10005       | 29           | nan         | nan          | 10003     | 0
# 100       | RAINFOREST_RESIN | 9996        | 2            | 9995        | 22           | nan         | nan          | 10004       | 2            | 10005       | 22           | nan         | nan          | 10000     | 0
# 200       | RAINFOREST_RESIN | 9995        | 20           | nan         | nan          | nan         | nan          | 10005       | 20           | nan         | nan          | nan         | nan          | 10000     | 0
# ...

# %%
rainforest_resin_fair_value = np.mean(rainforest_resin.column('mid_price'))
rainforest_resin_fair_value
# Out:
# 10000.053749999999

# %%
kelp = table.where('product', 'KELP')
kelp_fair_value = np.mean(kelp.column('mid_price'))
kelp_fair_value
# Out:
# 2019.0519999999999

# %%
kelp
# Out:
# timestamp | product | bid_price_1 | bid_volume_1 | bid_price_2 | bid_volume_2 | bid_price_3 | bid_volume_3 | ask_price_1 | ask_volume_1 | ask_price_2 | ask_volume_2 | ask_price_3 | ask_volume_3 | mid_price | profit_and_loss
# 0         | KELP    | 2028        | 1            | 2026        | 2            | 2025        | 29           | 2029        | 31           | nan         | nan          | nan         | nan          | 2028.5    | 0
# 100       | KELP    | 2025        | 24           | nan         | nan          | nan         | nan          | 2028        | 2            | 2029        | 22           | nan         | nan          | 2026.5    | 0
# 200       | KELP    | 2025        | 22           | nan         | nan          | nan         | nan          | 2028        | 20           | nan         | nan          | nan         | nan          | 2026.5    | 0
# ...

# %%
kelp.scatter('timestamp', 'mid_price', fit_line=True)

# %%
# Filter the DataFrame for rows where the product is 'RAINFOREST_RESIN'
rainforest_resin_df = df[df['product'] == 'RAINFOREST_RESIN']

# Plot the filtered DataFrame
rainforest_resin_df.plot(x='timestamp', y='mid_price', title='RAINFOREST_RESIN Mid Price Over Time')
# Out:
# <Axes: title={'center': 'RAINFOREST_RESIN Mid Price Over Time'}, xlabel='timestamp'>

# %%
kelp_df = df[df['product'] == 'KELP']
kelp_df.plot(x='timestamp', y='mid_price', title='KELP Mid Price Over Time')
# Plot the filtered DataFrame
# Out:
# <Axes: title={'center': 'KELP Mid Price Over Time'}, xlabel='timestamp'>

# %%
import plotly.express as px

# Create a scatter plot with a trend line for RAINFOREST_RESIN 
fig = px.scatter(rainforest_resin_df, x='timestamp', y='mid_price', trendline='ols', title='RAINFOREST_RESIN Mid Price Over Time')
fig.show()
# Create a scatter plot with a trend line for KELP
fig = px.scatter(kelp_df, x='timestamp', y='mid_price', trendline='ols', title='KELP Mid Price Over Time')
fig.show()
p

# %%
kelp_value = kelp_df['mid_price'].mean()
kelp_value
# Out:
# 2019.0519999999999

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import pandas as pd

# Function to determine fair value using linear regression
def calculate_fair_value(timestamps, prices):
    """
    Calculate the fair value of a stock using linear regression.
    
    Parameters:
    timestamps (array): Time values
    prices (array): Mid prices
    
    Returns:
    model: Trained linear regression model
    fair_values: Predicted fair values for the given timestamps
    """
    # Reshape timestamps for sklearn
    X = np.array(timestamps).reshape(-1, 1)
    
    # Create and train the linear regression model
    model = LinearRegression()
    model.fit(X, prices)
    
    # Calculate fair values
    fair_values = model.predict(X)
    
    print(f"Fair value model - Slope: {model.coef_[0]:.8f}, Intercept: {model.intercept_:.6f}")
    return model, fair_values

# Function to predict future stock values
def predict_future_values(model_type, timestamps, prices, future_timestamps, degree=3):
    """
    Predict future stock values using either linear or polynomial regression.
    
    Parameters:
    model_type (str): 'linear' or 'polynomial'
    timestamps (array): Historical time values
    prices (array): Historical mid prices
    future_timestamps (array): Future time points to predict
    degree (int): Degree of polynomial (only for 'polynomial' model)
    
    Returns:
    model: The trained prediction model
    predictions: Predicted values for future_timestamps
    """
    # Reshape data
    X = np.array(timestamps).reshape(-1, 1)
    X_future = np.array(future_timestamps).reshape(-1, 1)
    
    if model_type.lower() == 'linear':
        model = LinearRegression()
        model.fit(X, prices)
    elif model_type.lower() == 'polynomial':
        model = make_pipeline(PolynomialFeatures(degree=degree), LinearRegression())
        model.fit(X, prices)
    else:
        raise ValueError("model_type must be either 'linear' or 'polynomial'")
    
    predictions = model.predict(X_future)
    return model, predictions

# Function to visualize the data, fair value, and predictions
def visualize_stock_analysis(timestamps, prices, fair_values, future_timestamps=None, future_values=None):
    """
    Create a visualization of stock data with fair value and optional future predictions.
    """
    plt.figure(figsize=(12, 8))
    
    # Plot historical data
    plt.scatter(timestamps, prices, color='blue', alpha=0.5, label='Mid Prices')
    
    # Plot fair value line
    plt.plot(timestamps, fair_values, color='red', label='Fair Value (Linear Regression)')
    #plt.plot(future_timestamps, fair_values, color='red', label='Fair Value (Future Prediction)')
    
    # Plot future predictions if provided
    if future_timestamps is not None and future_values is not None:
        plt.plot(future_timestamps, future_values, color='green', label='Future Prediction')
    
    plt.title('KELP Stock Analysis')
    plt.xlabel('Timestamp')
    plt.ylabel('Mid Price')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()


# df = pd.read_csv('your_kelp_data.csv')  # Uncomment and use your data source
# timestamps = df['timestamp'].values
# prices = df['mid_price'].values

# timestamps = np.linspace(0, 200000, 500)  # Example timestamps

# prices = 2025 - 0.00002 * timestamps + np.random.normal(0, 5, 500)  # Example prices
# # Example future timestamps for prediction
# future_timestamps = np.linspace(200000, 300000, 100)
# # Example future timestamps for prediction
# # Calculate fair value
# fair_model, fair_values = calculate_fair_value(timestamps, prices)
# # Predict future values using linear regression
# linear_model, future_linear_values = predict_future_values('linear', timestamps, prices, future_timestamps)
# # Predict future values using polynomial regression
# poly_model, future_poly_values = predict_future_values('polynomial', timestamps, prices, future_timestamps, degree=3)
# # Visualize the analysis
# visualize_stock_analysis(timestamps, prices, fair_values, future_timestamps, future_poly_values)

# %%
timestamps = kelp_df['timestamp'].values
prices = kelp_df['mid_price'].values

#timestamps = np.linspace(0, 200000, 500)  # Example timestamps

#prices = 2025 - 0.00002 * timestamps + np.random.normal(0, 5, 500)  # Example prices
# Example future timestamps for prediction
future_timestamps = np.linspace(200000, 300000, 100)
# Example future timestamps for prediction
# Calculate fair value
fair_model, fair_values = calculate_fair_value(timestamps, prices)
# Predict future values using linear regression
linear_model, future_linear_values = predict_future_values('linear', timestamps, prices, future_timestamps)
# Predict future values using polynomial regression
poly_model, future_poly_values = predict_future_values('polynomial', timestamps, prices, future_timestamps, degree=3)
# Visualize the analysis
visualize_stock_analysis(timestamps, prices, fair_values, future_timestamps, future_poly_values)
# Out:
# Fair value model - Slope: -0.00003083, Intercept: 2022.133735

# %%
timestamps = rainforest_resin_df['timestamp'].values
prices = rainforest_resin_df['mid_price'].values

#timestamps = np.linspace(0, 200000, 500)  # Example timestamps

#prices = 2025 - 0.00002 * timestamps + np.random.normal(0, 5, 500)  # Example prices
# Example future timestamps for prediction
future_timestamps = np.linspace(200000, 300000, 100)
# Example future timestamps for prediction
# Calculate fair value
fair_model, fair_values = calculate_fair_value(timestamps, prices)
# Predict future values using linear regression
linear_model, future_linear_values = predict_future_values('linear', timestamps, prices, future_timestamps)
# Predict future values using polynomial regression
poly_model, future_poly_values = predict_future_values('polynomial', timestamps, prices, future_timestamps, degree=3)
# Visualize the analysis
visualize_stock_analysis(timestamps, prices, fair_values, future_timestamps, future_poly_values)
# Out:
# Fair value model - Slope: -0.00000086, Intercept: 10000.139312

# %%
# Cufflinks to predict future values
import cufflinks as cf
from plotly.offline import plot

# Set the offline mode for Plotly
cf.go_offline()

# Create a DataFrame for the KELP data
kelp_help_df = pd.DataFrame({
    'timestamp': timestamps,
    'mid_price': prices
})

# Create a DataFrame for the RAINFOREST_RESIN data
rainforest_resin_help_df = pd.DataFrame({
    'timestamp': timestamps,
    'mid_price': prices
})

# Create a scatter plot with a trend line for KELP using Cufflinks
kelp_fig = kelp_help_df.iplot(
    x='timestamp',
    y='mid_price',
    mode='markers',
    asFigure=True,
    title='KELP Mid Price Over Time'
)
kelp_fig.update_layout(
    title=dict(text='KELP Mid Price Over Time', font=dict(size=16))
)
kelp_fig.add_scatter(x=kelp_df['timestamp'], y=fair_values, mode='lines', name='Fair Value (Linear Regression)')
# Errors for some reason that I do not understand.
# Show the plot
plot(kelp_fig, filename='kelp_mid_price.html')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 21
#      15 rainforest_resin_help_df = pd.DataFrame({
#      16     'timestamp': timestamps,
#      17     'mid_price': prices
#      18 })
#      20 # Create a scatter plot with a trend line for KELP using Cufflinks
# ---> 21 kelp_fig = kelp_help_df.iplot(
#      22     x='timestamp',
#      23     y='mid_price',
#      24     mode='markers',
#      25     asFigure=True,
#      26     title='KELP Mid Price Over Time'
#      27 )
#      28 kelp_fig.update_layout(
# ...
